# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudhr20/Brain-Tumor-Detection-Using-Faster-RCNN/blob/master/transfer_brain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
root_dir = "/content/gdrive/My Drive"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# save('/content/gdrive/My Drive/data/mri-brain/1.mat','-v7')
# import scipy.io 
# d = io.loadmat('/content/gdrive/My Drive/data/mri-brain/1.mat')

# %%
import h5py
import numpy as np

# %%
filepath = '/content/gdrive/My Drive/data/mri-brain/100.mat'
arrays = {}
f = h5py.File(filepath)
data = f.get('cjdata/image')
label = f.get('cjdata/label')
border = f.get('cjdata/tumorBorder')
mask = f.get('cjdata/tumorMask')
data = np.array(data)
label = np.array(label)
border = np.array(border)
mask = np.array(mask)
# print(data)
# data = tables.open_file('/content/gdrive/My Drive/data/mri-brain/1.mat')
# print(data.root.cjdata.tumorBorder)
# print(arrays['cjdata'][1])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(25, 4))
# plt.add_subplot()
# ax = fig.add_subplot(2, 20/2, xticks=[], yticks=[])
# helper function to un-normalize and display an image
  # convert from Tensor image
# ax.set_title(label)

plt.imshow(data)
print(label)
print(border)
# print(mask)
# Out:
# [[1.]]
# [[193.26370733 175.80763053 185.15910024 180.17164973 183.91223762
#   184.53566893 184.53566893 198.87458915 184.53566893 210.0963528
#   180.17164973 221.94154777 178.9247871  233.16331142 180.17164973
#   238.77419324 187.02939419 249.9959569  193.26370733 259.97085792
#   197.62772652 266.82860237 205.10890229 266.82860237 211.96664674
#   260.59428923 215.08380331 253.73654478 218.20095988 241.2679185
#   216.95409726 230.04615485 213.83694069 220.69468514 210.71978412
#   208.22605886 209.47292149 193.26370733 203.86203966 181.41851236
#   196.3808639  177.67792448]]

# %%
class MyDataset(Dataset):
    def __init__(self, mat_paths):
        self.paths = mat_paths
        
    def __getitem__(self, index):
        # Load .mat
        f = h5py.File(self.paths[index])
        data = f.get('')
        x = torch.from_numpy(data['Training_patches'])
        y = torch.from_numpy(data['labels'])
        
        return x, y
    
    def __len__(self):
        return len(self.paths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f079605402ab> in <module>()
# ----> 1 class MyDataset(Dataset):
#       2     def __init__(self, mat_paths):
#       3         self.paths = mat_paths
#       4
#       5     def __getitem__(self, index):
#
# NameError: name 'Dataset' is not defined
